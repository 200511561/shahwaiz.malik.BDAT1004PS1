// %% [markdown]
// ## Question 1
// What data type is each of the following?

// %% [markdown]
// #####
// 5 integer
// 5.0 float
// 5 > 1 boolean
// '5' string
// 5 * 2 integer
// '5' * 2 string
// '5' + '2' string
// 5 / 2 float
// 5 % 2 integer
// {5, 2, 1} list
// 5 == 3 boolean
// Pi (the number) float

// %% [markdown]
// ![1a.png](attachment:1a.png)

// %% [markdown]
// ## Question 2a
// How many letters are there in 'Supercalifragilisticexpialidocious'?

// %%
String string1 = "Supercalifragilisticexpialidocious";
        int letter_count = 0;
  
        for (int i = 0; i < string1.Length; i++)
        {
            if (string1[i] != ' ')
                letter_count++;
        }

        Console.WriteLine("Total letters in string are: " + letter_count);
// Out:
// Total letters in string are: 34

// %% [markdown]
// ![2a-3.png](attachment:2a-3.png)

// %% [markdown]
// ## 2b.
// Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

// %%
        String string1 = "Supercalifragilisticexpialidocious";
        String substring = "ice";
        Boolean result = string1.Contains(substring);
        Console.WriteLine($"Does {string1} contains  {substring} ::::: {result}");
// Out:
// Does Supercalifragilisticexpialidocious contains  ice ::::: True

// %% [markdown]
// ![2b.png](attachment:2b.png)

// %% [markdown]
// ## 2c.
//  Which of the following words is the longest:
//  Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
//  Bababadalgharaghtakamminarronnkonn?

// %%
int counter = 0;
string [] stringList = { "Supercalifragilisticexpialidocious", "Honorificabilitudinitatibus", "Bababadalgharaghtakamminarronnkonn" };

           int length = stringList.Length;
 
            for (int i = 0; i < length; i++)
            {
                if(stringList[i].Length>max)
                {
                   int max = stringList[i].Length;
                     counter = i;
                }
            }
 
            
            Console.WriteLine("The longest word is ::: {0} \n Length of longest word is ::: {1}",stringList[counter],max);
            Console.ReadLine();
// Out:
// The longest word is ::: Supercalifragilisticexpialidocious
//  Length of longest word is ::: 34

// %% [markdown]
// ![2c-2.png](attachment:2c-2.png)

// %% [markdown]
// ## 2d:
//   Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
//  'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %%
            List<string> listptr = new List<string>();
            listptr.Add("Berlioz");
            listptr.Add("Borodin");
            listptr.Add("Brian");
            listptr.Add("Bartok");
            listptr.Add("Bellini");
            listptr.Add("Buxtehude");
            listptr.Add("Bernstein");
            listptr.Sort();
            Console.WriteLine("Alphabetically First composer will be : "+listptr[0]);
            listptr.Reverse();
            Console.WriteLine("Alphabetically Last composer will be : "+listptr[0]);
// Out:
// Alphabetically First composer will be : Bartok
// Alphabetically Last composer will be : Buxtehude

// %% [markdown]
// ![2d.png](attachment:2d.png)

// %% [markdown]
// ## Question 3
// Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
// sides of a triangle and returns the area of the triangle. By Heron's formula, the area
// of a triangle with side lengths a, b, and c is
// s(s - a)(s -b)(s -c)
// , where
// s = (a+b+c)/2.

// %%
public static void AreaOfTriangle(int a,int b,int c)
        {
            var s = (a + b + c) / 2;
            var area = Math.Sqrt(s * ((s - a) * (s - b) * (s - c)));
            Console.WriteLine(area);
        }
      AreaOfTriangle(2,2,2)
// Out:
// 1.7320508075688772

// %% [markdown]
// ![3a.png](attachment:3a.png)

// %% [markdown]
// ## Question 4
// Write a program in C# Sharp to separate odd and even integers in separate arrays.
// Go to the editor

// %%
List<int> lst = new List<int>();
    List<int> even = new List<int>();
    List<int> odd = new List<int>();
    Console.Write("Input the numbers : ");
    var num = Console.ReadLine();
    Console.WriteLine("Input number " + num);
    var i = 0;
    while (i < int.Parse(num))
    {
        Console.Write("number:  ");
        string value_entered = Console.ReadLine();
        lst.Add(Convert.ToInt32(value_entered));
        i++;
    }
    foreach (var value in lst)
    {
        if (value % 2 == 0)
        {
            even.Add(value);
        }
        else
        {
            odd.Add(value);
        }
    }

Console.WriteLine("odd numbers are:");

foreach (var value in odd)
{
    Console.Write(value + " ");
}
Console.WriteLine(" ");
Console.WriteLine("Even numbers are:");

    foreach (var value in even)
    {
        Console.Write(value + " ");
    }
// Out:
// Input the numbers : Input number
// Unhandled Exception
// Value cannot be null. (Parameter 's')
//    at System.Int32.Parse(String s)
//    at Submission#27.<<Initialize>>d__0.MoveNext()
// --- End of stack trace from previous location where exception was thrown ---
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %% [markdown]
// ![4a.png](attachment:4a.png)

// %% [markdown]
// ## Question 5 a
// a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
// depending on whether the point (x,y) lies in the rectangle with lower left
// corner (x1,y1) and upper right corner (x2,y2).

// %%
public static bool inside(int x,int y,int x1,int y1,int x2,int y2)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
            {
                return true;
            }
            else
                return false;
        }
inside(3,45,2,5,5,2)
// Out:
// False

// %% [markdown]
// ![5a.png](attachment:5a.png)

// %% [markdown]
// ## Question 5b
// Use function inside() from part a. to write an expression that tests whether
// the point (1,1) lies in both of the following rectangles: one with lower left
// corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
// left corner (0.5, 0.2) and upper right corner (1.1, 2).

// %%
public static void inside1(int x, int y, double x1, double y1, double x2, double y2,double x3,double y3,double x4,double y4)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
            {
                if(x > x3 && x < x4 && y > y3 && y < y4)
                {
                    Console.WriteLine("True");
                }
            }
            else
                Console.WriteLine("False");
        }
        
inside1(1,1,0.3,0.5,1.1,0.7,0.5,0.2,1.1,2)
// Out:
// False

// %% [markdown]
// ![5b.png](attachment:5b.png)
